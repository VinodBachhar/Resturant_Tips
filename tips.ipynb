# %%
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv('tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x="total_bill", y="tip",data=df)
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x="total_bill",y="tip",col="time",data=df)
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x="total_bill",y="tip",hue="sex",data=df)
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x="total_bill",y="tip",size="size",data=df)
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x="total_bill",y="tip",size="time",data=df)
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x="total_bill",y="tip",style="time",data=df)
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a visualilazation
sns.relplot(
data=df,
    x="total_bill",y="tip",col="time",
    hue="smoker",style="smoker",size="size"
)
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lineplot(x='size',y='tip',data=df)
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
# color palette
sns.color_palette('spring')
# Out:
# [(1.0, 0.1411764705882353, 0.8588235294117648),
#  (1.0, 0.28627450980392155, 0.7137254901960784),
#  (1.0, 0.42745098039215684, 0.5725490196078431),
#  (1.0, 0.5725490196078431, 0.4274509803921569),
#  (1.0, 0.7137254901960784, 0.28627450980392155),
#  (1.0, 0.8588235294117647, 0.14117647058823535)]

# %%
sns.color_palette('winter')
# Out:
# [(0.0, 0.1411764705882353, 0.9294117647058824),
#  (0.0, 0.28627450980392155, 0.8568627450980393),
#  (0.0, 0.42745098039215684, 0.7862745098039216),
#  (0.0, 0.5725490196078431, 0.7137254901960784),
#  (0.0, 0.7137254901960784, 0.6431372549019607),
#  (0.0, 0.8588235294117647, 0.5705882352941176)]

# %%
sns.color_palette('muted')
# Out:
# [(0.2823529411764706, 0.47058823529411764, 0.8156862745098039),
#  (0.9333333333333333, 0.5215686274509804, 0.2901960784313726),
#  (0.41568627450980394, 0.8, 0.39215686274509803),
#  (0.8392156862745098, 0.37254901960784315, 0.37254901960784315),
#  (0.5843137254901961, 0.4235294117647059, 0.7058823529411765),
#  (0.5490196078431373, 0.3803921568627451, 0.23529411764705882),
#  (0.8627450980392157, 0.49411764705882355, 0.7529411764705882),
#  (0.4745098039215686, 0.4745098039215686, 0.4745098039215686),
#  (0.8352941176470589, 0.7333333333333333, 0.403921568627451),
#  (0.5098039215686274, 0.7764705882352941, 0.8862745098039215)]

# %%
sns.color_palette('ocean')
# Out:
# [(0.0, 0.28823529411764703, 0.1411764705882353),
#  (0.0, 0.07058823529411767, 0.28627450980392155),
#  (0.0, 0.14117647058823524, 0.42745098039215684),
#  (0.0, 0.35882352941176465, 0.5725490196078431),
#  (0.14117647058823524, 0.5705882352941176, 0.7137254901960784),
#  (0.5764705882352938, 0.7882352941176469, 0.8588235294117647)]

# %%
sns.catplot(x='sex',y='total_bill',kind='bar',data=df,palette='muted',order=['Male','Female'])
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(y='sex',x='total_bill',kind='bar',data=df,palette='muted',order=['Male','Female'])
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.barplot(x='sex',y='total_bill',data=df,palette='muted',order=['Male','Female'])
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex',y='total_bill',data=df,palette='muted')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.catplot(x='sex',y='total_bill',kind='box',data=df)
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='sex',y='total_bill',kind='strip', data=df,order=['Male','Female'])
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='sex',y='total_bill',kind='swarm', data=df,order=['Male','Female'])
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='sex',y='total_bill',kind='violin', data=df,order=['Male','Female'])
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='sex',y='total_bill',kind='point', data=df,order=['Male','Female'])
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Displot
sns.displot(x='tip',data=df)
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(x='tip',hue='sex',data=df)
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(x='tip',hue='sex',kind='kde', data=df)
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(x='tip',hue='sex',kind='ecdf', data=df)
# Out:
# C:\Users\Rowtech\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Count plot
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# Seaborn heatmap
corrMatrix=df.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 # Seaborn heatmap
# ----> 2 corrMatrix=df. corr()
#       3 sns.heatmap(corrMatrix, annot=True)
#       4 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
sns.set_style('whitegrid')
